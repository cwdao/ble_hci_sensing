# %% [markdown]
# # 此 notebook 已拆分
#
# 原 `glb_load_cs_saved_frames_show_analysis.ipynb` 已拆为三个独立 notebook：
#
# | 文件 | 用途 |
# |------|------|
# | [`glb_cs_load_and_explore.ipynb`](./glb_cs_load_and_explore.ipynb) | 加载数据、单通道快速探索 |
# | [`glb_cs_segment_breath_analysis.ipynb`](./glb_cs_segment_breath_analysis.ipynb) | 分段处理 + BPM/IE/apnea 指标 + 误差评估 |
# | [`glb_cs_full_pipeline_demo.ipynb`](./glb_cs_full_pipeline_demo.ipynb) | 全量滤波算法演示（**冻结，不再修改**） |
#
# 公共函数位于 `src/ble_analysis/`。
